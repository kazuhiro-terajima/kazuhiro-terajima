# %%
import matplotlib.pyplot as plt
import numpy as np

# plt.style.use('_mpl-gallery')

# make data
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)

# plot:
fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
# plot:

fig = plt.figure()
ax  = fig.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#CSVファイルをUTF-8形式で読み込む
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/年間快晴日数東京新潟.csv')

# data

# %%
# plot:

x1=data['東京都']
x2=data['新潟県']

fig, axes = plt.subplots(1,2)

axes[0].hist(x1,bins=8, linewidth=1, edgecolor="white")
axes[1].hist(x2,bins=8, linewidth=1, edgecolor="white")

axes[0].set(xlim=(0, 100), ylim=(0, 20))
axes[1].set(xlim=(0, 100), ylim=(0, 20))

'''
axes[0].set(xlim=(0, 100), xticks=np.arange(1, 10),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))
axes[1].set(xlim=(0, 100), xticks=np.arange(1, 10),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))
'''

plt.show()

# %%
# plot:

x1=data['東京都']
x2=data['新潟県']

fig, axes = plt.subplots(1,2)

axes[0].hist(x1,bins=8, linewidth=1, edgecolor="white")
axes[0].hist(x2,bins=8, linewidth=1, edgecolor="white")

axes[0].set(xlim=(0, 100), ylim=(0, 20))
axes[0].set(xlim=(0, 100), ylim=(0, 20))

'''
axes[0].set(xlim=(0, 100), xticks=np.arange(1, 10),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))
axes[1].set(xlim=(0, 100), xticks=np.arange(1, 10),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))
'''

plt.show()
